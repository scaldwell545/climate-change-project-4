# %%
#imports
import os
import pandas as pd
from datetime import datetime
import numpy as np

# %%
#reading csvs in with dates as datetimes
Aotizhongxin = pd.read_csv("Resources/Aotizhongxin.csv", parse_dates= {"date" : ["year","month","day", "hour"]}, date_parser=lambda x: pd.datetime.strptime(x, '%Y %m %d %H'))
Changping = pd.read_csv("Resources/Changping.csv", parse_dates= {"date" : ["year","month","day", "hour"]}, date_parser=lambda x: pd.datetime.strptime(x, '%Y %m %d %H'))
Dingling = pd.read_csv("Resources/Dingling.csv", parse_dates= {"date" : ["year","month","day", "hour"]}, date_parser=lambda x: pd.datetime.strptime(x, '%Y %m %d %H'))
Dongsi = pd.read_csv("Resources/Dongsi.csv", parse_dates= {"date" : ["year","month","day", "hour"]}, date_parser=lambda x: pd.datetime.strptime(x, '%Y %m %d %H'))
Guanyuan = pd.read_csv("Resources/Guanyuan.csv", parse_dates= {"date" : ["year","month","day", "hour"]},  date_parser=lambda x: pd.datetime.strptime(x, '%Y %m %d %H'))
Gucheng = pd.read_csv("Resources/Gucheng.csv", parse_dates= {"date" : ["year","month","day", "hour"]}, date_parser=lambda x: pd.datetime.strptime(x, '%Y %m %d %H'))
Huairou = pd.read_csv("Resources/Huairou.csv", parse_dates= {"date" : ["year","month","day", "hour"]}, date_parser=lambda x: pd.datetime.strptime(x, '%Y %m %d %H'))
Nongzhanguan = pd.read_csv("Resources/Nongzhanguan.csv", parse_dates= {"date" : ["year","month","day", "hour"]}, date_parser=lambda x: pd.datetime.strptime(x, '%Y %m %d %H'))
Shunyi = pd.read_csv("Resources/Shunyi.csv", parse_dates= {"date" : ["year","month","day", "hour"]}, date_parser=lambda x: pd.datetime.strptime(x, '%Y %m %d %H'))
Tiantan = pd.read_csv("Resources/Tiantan.csv", parse_dates= {"date" : ["year","month","day", "hour"]}, date_parser=lambda x: pd.datetime.strptime(x, '%Y %m %d %H'))
Wanliu = pd.read_csv("Resources/Wanliu.csv", parse_dates= {"date" : ["year","month","day", "hour"]}, date_parser=lambda x: pd.datetime.strptime(x, '%Y %m %d %H'))
Wanshouxigong = pd.read_csv("Resources/Wanshouxigong.csv", parse_dates= {"date" : ["year","month","day", "hour"]}, date_parser=lambda x: pd.datetime.strptime(x, '%Y %m %d %H'))
# Out:
# <ipython-input-57-a8711dec95c8>:1: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   Aotizhongxin = pd.read_csv("PRSA2017_Data/Aotizhongxin.csv", parse_dates= {"date" : ["year","month","day", "hour"]}, date_parser=lambda x: pd.datetime.strptime(x, '%Y %m %d %H'))
# <ipython-input-57-a8711dec95c8>:2: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   Changping = pd.read_csv("PRSA2017_Data/Changping.csv", parse_dates= {"date" : ["year","month","day", "hour"]}, date_parser=lambda x: pd.datetime.strptime(x, '%Y %m %d %H'))
# <ipython-input-57-a8711dec95c8>:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
# ...

# %%
#checking to see if the datetime read in correctly
Aotizhongxin.head()
# Out:
#                  date  No  PM2.5  PM10   SO2   NO2     CO    O3  TEMP    PRES  \
# 0 2013-03-01 00:00:00   1    4.0   4.0   4.0   7.0  300.0  77.0  -0.7  1023.0
# 1 2013-03-01 01:00:00   2    8.0   8.0   4.0   7.0  300.0  77.0  -1.1  1023.2
# 2 2013-03-01 02:00:00   3    7.0   7.0   5.0  10.0  300.0  73.0  -1.1  1023.5
# 3 2013-03-01 03:00:00   4    6.0   6.0  11.0  11.0  300.0  72.0  -1.4  1024.5
# 4 2013-03-01 04:00:00   5    3.0   3.0  12.0  12.0  300.0  72.0  -2.0  1025.2
#
#    DEWP  RAIN   wd  WSPM       station
# 0 -18.8   0.0  NNW   4.4  Aotizhongxin
# 1 -18.2   0.0    N   4.7  Aotizhongxin
# 2 -18.2   0.0  NNW   5.6  Aotizhongxin
# 3 -19.4   0.0   NW   3.1  Aotizhongxin
# 4 -19.5   0.0    N   2.0  Aotizhongxin

# %%
# putting csvs into a list to iterate 
#files = [

	#Aotizhongxin,
	#Changping,
	#Dingling,
	#Dongsi,
	#Guanyuan,
	#Gucheng,
	#Huairou,
	#Nongzhanguan,
	#Shunyi,
	#Tiantan,
	#Wanliu,
	#Wanshouxigong	
#]

# %%
#drop extraneous columns
Aotizhongxin = Aotizhongxin.drop(columns=['No', 'WSPM', 'wd', 'DEWP', 'RAIN', 'station', 'PRES'], axis=1)
Aotizhongxin = Aotizhongxin.dropna()

Changping = Changping.drop(columns=['No', 'WSPM', 'wd', 'DEWP', 'RAIN', 'station', 'PRES'], axis=1)
Changping = Changping.dropna()

Dingling = Dingling.drop(columns=['No', 'WSPM', 'wd', 'DEWP', 'RAIN', 'station', 'PRES'], axis=1)
Dingling = Dingling.dropna()

Dongsi = Dongsi.drop(columns=['No', 'WSPM', 'wd', 'DEWP', 'RAIN', 'station', 'PRES'], axis=1)
Dongsi = Dongsi.dropna()

Guanyuan = Guanyuan.drop(columns=['No', 'WSPM', 'wd', 'DEWP', 'RAIN', 'station', 'PRES'], axis=1)
Guanyuan = Guanyuan.dropna()

Gucheng = Gucheng.drop(columns=['No', 'WSPM', 'wd', 'DEWP', 'RAIN', 'station', 'PRES'], axis=1)
Gucheng = Gucheng.dropna()

Huairou = Huairou.drop(columns=['No', 'WSPM', 'wd', 'DEWP', 'RAIN', 'station', 'PRES'], axis=1)
Huairou = Huairou.dropna()

Nongzhanguan = Nongzhanguan.drop(columns=['No', 'WSPM', 'wd', 'DEWP', 'RAIN', 'station', 'PRES'], axis=1)
Nongzhanguan = Nongzhanguan.dropna()

Shunyi = Shunyi.drop(columns=['No', 'WSPM', 'wd', 'DEWP', 'RAIN', 'station', 'PRES'], axis=1)
Shunyi = Shunyi.dropna()

Tiantan = Tiantan.drop(columns=['No', 'WSPM', 'wd', 'DEWP', 'RAIN', 'station', 'PRES'], axis=1)
Tiantan = Tiantan.dropna()

Wanliu = Wanliu.drop(columns=['No', 'WSPM', 'wd', 'DEWP', 'RAIN', 'station', 'PRES'], axis=1)
Wanliu = Wanliu.dropna()

Wanshouxigong = Wanshouxigong.drop(columns=['No', 'WSPM', 'wd', 'DEWP', 'RAIN', 'station', 'PRES'], axis=1)
Wanshouxigong = Wanshouxigong.dropna()

# %%
Wanshouxigong.head()
# Out:
#                  date  PM2.5  PM10  SO2   NO2     CO    O3  TEMP
# 0 2013-03-01 00:00:00    9.0   9.0  6.0  17.0  200.0  62.0   0.3
# 1 2013-03-01 01:00:00   11.0  11.0  7.0  14.0  200.0  66.0  -0.1
# 5 2013-03-01 05:00:00   10.0  10.0  4.0   8.0  200.0  64.0  -1.6
# 6 2013-03-01 06:00:00    8.0   8.0  6.0  13.0  300.0  61.0  -2.4
# 7 2013-03-01 07:00:00    8.0   8.0  8.0  20.0  300.0  54.0  -0.8
